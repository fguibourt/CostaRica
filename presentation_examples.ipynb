# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime, timedelta

# %%
data = pd.read_csv("data/all_anonymized_2015_11_2017_03.csv", encoding="Latin-1")
# Out:
# /home/hdh7/Documents/IMT 3eme/big-data/used-cars-ebay/.venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (7,8,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.isna().sum()
# Out:
# maker                   518915
# model                  1133361
# mileage                 362584
# manufacture_year        370578
# engine_displacement     743414
# engine_power            554877
# body_type              1122914
# color_slug             3343411
# stk_year               1708156
# transmission            741630
# door_count              614373
# seat_count              749489
# fuel_type              1847606
# date_created                 0
# date_last_seen               0
# price_eur                    0
# dtype: int64

# %%
model_sum = data.model.groupby(data.model).count()

# %%
num_maker_per_model = data.groupby(['model','maker']).count().reset_index()[['model','maker']].groupby('model').count().reset_index().sort_values(by='maker',ascending='False')

# %%
num_maker_per_model[num_maker_per_model.maker > 1]
# Out:
#               model  maker
# 431              es      2
# 522              gs      2
# 977              x1      2
# 22              126      2
# 475               g      2
# 463      freelander      2
# 450           fabia      2
# 972        wrangler      2
# 980              x4      2
# 981              x5      2
# 982              x6      2
# 987           xedos      2
# 69              306      2
# 4               106      2
# 40                2      2
# 516    grand-vitara      2
# 43             2008      2
# 47              208      2
# 65             300c      2
# 460          fortwo      2
# 434          espace      2
# 45              206      2
# 458         forfour      2
# 70              307      2
# 64             3008      2
# 377       crossfire      2
# 923         transit      2
# 164              75      2
# 626          matrix      2
# 541             i30      2
# ..              ...    ...
# 607              m3      2
# 94              400      2
# ...

# %%
data[data.model == 'gt'].groupby('maker').count()
# Out:
#             model  mileage  manufacture_year  engine_displacement  \
# maker
# alfa-romeo    205      184               186                  147
# ford          230      219               228                  137
# opel          221      206               212                  128
#
#             engine_power  body_type  color_slug  stk_year  transmission  \
# maker
# alfa-romeo           189        205          41        12           146
# ford                 146         76           0       173           145
# opel                 144        102           1       144           150
#
#             door_count  seat_count  fuel_type  date_created  date_last_seen  \
# maker
# alfa-romeo         123         123         94           205             205
# ford               196         194        157           230             230
# opel               192         184        128           221             221
#
#             price_eur
# maker
# alfa-romeo        205
# ford              230
# ...

# %%
data[data.model == 'octavia'].groupby('maker').count()
# Out:
#          model  mileage  manufacture_year  engine_displacement  engine_power  \
# maker
# audi         2        0                 0                    0             0
# bmw          2        1                 2                    2             2
# ford         1        1                 1                    1             1
# seat         1        1                 1                    1             1
# skoda   129554   105380            113435               112699        113564
# suzuki       1        1                 1                    0             0
# toyota       1        1                 0                    1             1
# volvo        1        0                 1                    0             0
#
#         body_type  color_slug  stk_year  transmission  door_count  seat_count  \
# maker
# audi            2           0         0             0           0           0
# bmw             2           0         1             0           0           0
# ...

# %%
data[data.model == '407'].groupby('maker').count()
# Out:
#          model  mileage  manufacture_year  engine_displacement  engine_power  \
# maker
# audi         1        1                 1                    1             1
# bmw          2        2                 2                    2             2
# peugeot   3804     3274              3513                 2868          3183
#
#          body_type  color_slug  stk_year  transmission  door_count  \
# maker
# audi             1           0         0             1           0
# bmw              2           0         0             2           0
# peugeot       3804         408       613          2914        2494
#
#          seat_count  fuel_type  date_created  date_last_seen  price_eur
# maker
# audi              0          1             1               1          1
# bmw               0          2             2               2          2
# peugeot        2375        927          3804            3804       3804
